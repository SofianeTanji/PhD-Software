# %% [markdown]
# # Experiment 2: Any number of groups

# %%
from experiments.experiment_2.plotter import plot_paired_effects, plot_results

# %%
plot_results(
    results_path="results_slsqp.jsonl",
    alpha=1,
)

# %%
summary_test = plot_paired_effects(results_path="results_slsqp.jsonl", split="test")
summary_train = plot_paired_effects(results_path="results_slsqp.jsonl", split="train")
